# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import os
from factories.formatter_factory import FormatterFactory
from single_dim_formatter import SingleDimFormatter
from stat_merger import StatMerger

# %% [markdown]
# ## Create instances

# %%
formatter_factory = FormatterFactory()
single_dim_formatter = SingleDimFormatter()
stat_merger = StatMerger("./../../../../../timeseries/new.csv")

# %% [markdown]
# ## Read csv file

# %%
csv_file_path = "./../../../../../assets/grafana_stats/constant-load/long/cpu/system/file.csv"

df = formatter_factory.prepare_data(csv_file_path)

print(df.head())
# Out:
#    cpu_system
# 0     0.00518
# 1     0.00516
# 2     0.00518
# 3     0.00501
# 4     0.00507

# %% [markdown]
# ## Merge all

# %%
base_path = "./../../../../../assets/grafana_stats/constant-load/long"

# %% [markdown]
# # Create new csv with all timeseries data

# %%
for root, dirs, files in os.walk(base_path):
    for file in files:
        file_path = os.path.join(root, file)
        df = formatter_factory.prepare_data(file_path)
        stat_merger.add_dataframe(df)

print(stat_merger.dataframes)   
stat_merger.create_time_series()
# Out:
# [     long_i_o_read
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ..             ...
# 248              0
# 249              0
# 250              0
# 251              0
# 252              0
#
# [253 rows x 1 columns],      long_i_o_write
# 0               400
# 1               403
# 2               403
# 3               403
# 4               403
# ..              ...
# 248             512
# 249             520
# 250             514
# 251             520
# 252             528
#
# [253 rows x 1 columns],      long_memory
# 0    12764622848
# 1    12751368192
# 2    12748492800
# 3    12752961536
# 4    12758626304
# ..           ...
# 248  12527370240
# 249  12527157248
# 250  12528062464
# 251  12531658752
# 252  12527710208
#
# [253 rows x 1 columns],      network_outgoing_pod_adservice  network_outgoing_pod_cartservice  \
# 0                               215                               498
# 1                               209                               498
# 2                               209                               498
# 3                               209                               482
# 4                               209                               479
# ..                              ...                               ...
# 248                            5857                             17522
# 249                            5849                             17522
# 250                            5849                             17522
# 251                            5849                             17522
# 252                            5849                             17522
#
#      network_outgoing_pod_checkoutservice  \
# 0                                     526
# 1                                     521
# 2                                     521
# 3                                     521
# 4                                     521
# ..                                    ...
# 248                                 18876
# 249                                 18256
# 250                                 18989
# 251                                 18989
# 252                                 18989
#
#      network_outgoing_pod_currencyservice  network_outgoing_pod_emailservice  \
# 0                                     910                                343
# 1                                     921                                343
# 2                                     921                                343
# 3                                     921                                346
# 4                                     921                                346
# ..                                    ...                                ...
# 248                                 25930                               1465
# 249                                 25860                               1465
# 250                                 25860                               1465
# 251                                 25860                               1465
# 252                                 25860                               1465
#
#      network_outgoing_pod_frontend  network_outgoing_pod_loadgenerator  \
# 0                             8618                                5.47
# 1                             8333                               51.00
# 2                             8333                               55.30
# 3                             8333                               59.60
# 4                             8651                               63.90
# ..                             ...                                 ...
# 248                         483141                            27855.00
# 249                         483141                            27855.00
# 250                         483024                            27855.00
# 251                         483024                            27636.00
# 252                         483024                            27636.00
#
#      network_outgoing_pod_loadgenerator  network_outgoing_pod_loadgenerator  \
# 0                                 641.0                              2703.0
# 1                                 641.0                              2703.0
# 2                                 641.0                              2703.0
# 3                                 641.0                              2703.0
# 4                                 641.0                              2703.0
# ..                                  ...                                 ...
# 248                                 NaN                                 NaN
# 249                                 NaN                                 NaN
# 250                                 NaN                                 NaN
# 251                                 NaN                                 NaN
# 252                                 NaN                                 NaN
#
#      network_outgoing_pod_paymentservice  \
# 0                                    176
# 1                                    176
# 2                                    176
# 3                                    177
# 4                                    177
# ..                                   ...
# 248                                 1582
# 249                                 1582
# 250                                 1582
# 251                                 1582
# 252                                 1582
#
#      network_outgoing_pod_productcatalogservice  \
# 0                                          2175
# 1                                          2295
# 2                                          2295
# 3                                          2226
# 4                                          2275
# ..                                          ...
# 248                                      113104
# 249                                      113104
# 250                                      113104
# 251                                      113124
# 252                                      113152
#
#      network_outgoing_pod_recommendationservice  network_outgoing_pod_redis  \
# 0                                           594                         152
# 1                                           594                         148
# 2                                           594                         148
# 3                                           594                         148
# 4                                           594                         148
# ..                                          ...                         ...
# 248                                       14539                        4569
# 249                                       14545                        4569
# 250                                       14545                        4569
# 251                                       14517                        4569
# 252                                       14517                        4569
#
#      network_outgoing_pod_shippingservice
# 0                                     320
# 1                                     320
# 2                                     320
# 3                                     323
# 4                                     323
# ..                                    ...
# 248                                  5798
# 249                                  5798
# 250                                  5798
# 251                                  5798
# 252                                  5803
#
# [253 rows x 14 columns],      network_outgoing_system
# 0                      17877
# 1                      17753
# 2                      17757
# 3                      17684
# 4                      18052
# ..                       ...
# 248                   720238
# 249                   719546
# 250                   720162
# 251                   719936
# 252                   719969
#
# [253 rows x 1 columns],      cpu_pod_adservice  cpu_pod_cartservice  cpu_pod_checkoutservice  \
# 0              0.00236              0.00578                 0.000881
# 1              0.00236              0.00578                 0.000876
# 2              0.00230              0.00568                 0.000876
# 3              0.00232              0.00568                 0.000876
# 4              0.00238              0.00581                 0.000911
# ..                 ...                  ...                      ...
# 248            0.01890              0.09700                 0.027700
# 249            0.01890              0.09630                 0.027700
# 250            0.01890              0.09630                 0.027700
# 251            0.01890              0.09630                 0.027700
# 252            0.01890              0.09280                 0.027700
#
#      cpu_pod_currencyservice  cpu_pod_emailservice  cpu_pod_frontend  \
# 0                     0.0153               0.00197           0.00482
# 1                     0.0148               0.00197           0.00459
# 2                     0.0147               0.00195           0.00459
# 3                     0.0147               0.00195           0.00459
# 4                     0.0147               0.00195           0.00480
# ..                       ...                   ...               ...
# 248                   0.1990               0.00947           0.16500
# 249                   0.1990               0.00943           0.16500
# 250                   0.1990               0.00943           0.16500
# 251                   0.1990               0.00945           0.16500
# 252                   0.1990               0.00945           0.16500
#
#      cpu_pod_loadgenerator  cpu_pod_loadgenerator  cpu_pod_loadgenerator  \
# 0                  0.00572                0.00585                0.00917
# 1                  0.00629                0.00585                0.00917
# 2                  0.00686                0.00585                0.00917
# 3                  0.00469                0.00585                0.00917
# 4                  0.00505                0.00585                0.00917
# ..                     ...                    ...                    ...
# 248                0.12000                    NaN                    NaN
# 249                0.12000                    NaN                    NaN
# 250                0.12000                    NaN                    NaN
# 251                0.12000                    NaN                    NaN
# 252                0.12000                    NaN                    NaN
#
#      cpu_pod_paymentservice  cpu_pod_productcatalogservice  \
# 0                   0.00155                        0.00206
# 1                   0.00155                        0.00206
# 2                   0.00149                        0.00206
# 3                   0.00149                        0.00213
# 4                   0.00149                        0.00213
# ..                      ...                            ...
# 248                 0.05200                        0.07030
# 249                 0.05180                        0.07030
# 250                 0.05180                        0.07030
# 251                 0.05180                        0.07030
# 252                 0.05180                        0.07030
#
#      cpu_pod_recommendationservice  cpu_pod_redis  cpu_pod_shippingservice
# 0                          0.00358        0.00226                 0.000827
# 1                          0.00358        0.00226                 0.000827
# 2                          0.00358        0.00226                 0.000837
# 3                          0.00355        0.00226                 0.000837
# 4                          0.00355        0.00226                 0.000837
# ..                             ...            ...                      ...
# 248                        0.06700        0.00601                 0.014800
# 249                        0.06700        0.00579                 0.014800
# 250                        0.06700        0.00599                 0.014800
# 251                        0.06690        0.00599                 0.014800
# 252                        0.06690        0.00599                 0.014800
#
# [253 rows x 14 columns],      cpu_system
# 0       0.00518
# 1       0.00516
# 2       0.00518
# 3       0.00501
# 4       0.00507
# ..          ...
# 248     0.07070
# 249     0.07060
# 250     0.07060
# 251     0.07060
# 252     0.07030
#
# [253 rows x 1 columns],      long_pod_restart
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ..                ...
# 248                 0
# 249                 0
# 250                 0
# 251                 0
# 252                 0
#
# [253 rows x 1 columns]]
# CSV erfolgreich gespeichert unter: ./../../../../timeseries/new.csv

# %% [markdown]
# # Print new created csv

# %%
df = pd.read_csv("./../../../../../timeseries/grafana/new.csv")
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv("./../../../../../timeseries/new.csv")
#       2 df.head(5)
#
# File ~/Desktop/masterarbeit-cluster/performance-prediction/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Desktop/masterarbeit-cluster/performance-prediction/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Desktop/masterarbeit-cluster/performance-prediction/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Desktop/masterarbeit-cluster/performance-prediction/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Desktop/masterarbeit-cluster/performance-prediction/venv/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './../../../../../timeseries/new.csv'
